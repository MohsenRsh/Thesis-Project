# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.8.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     24.3.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# biopython                 1.84
# bleach                    6.2.0
# certifi                   2024.12.14
# cffi                      1.17.1
# charset-normalizer        3.4.1
# colorama                  0.4.6
# comm                      0.2.0
# contourpy                 1.3.1
# cycler                    0.12.1
# debugpy                   1.8.0
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 2.0.1
# fastjsonschema            2.21.1
# fonttools                 4.55.8
# fqdn                      1.5.1
# h11                       0.14.0
# ...
